# %% [markdown]
# #Netflix Data Analysis#

# %%
import numpy as np

# %%
import pandas as pd

# %%
data = pd.read_csv("netflix_titles_2021.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-f6470ff381a5> in <cell line: 1>()
# ----> 1 data = pd.read_csv("netflix_titles_2021.csv")
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
data.head(3)
# Out:
#                  Name    Year Age Rating Duration              Category      \
# 0       The Sea Beast  2022.0         7+   1h 59m  Kids & Family Movies NaN
# 1  Sonic the Hedgehog  2020.0         7+   1h 41m  Kids & Family Movies NaN
# 2       Tom and Jerry  2021.0         7+   1h 41m  Kids & Family Movies NaN
#
#    Unnamed: 6  Unnamed: 7 Unnamed: 8       Age Rating.1  ...  \
# 0         NaN         NaN        NaN                 7+  ...
# 1         NaN         NaN   Duration  Count of Duration  ...
# 2         NaN         NaN     1h 30m                  7  ...
#
#          Unnamed: 11  Unnamed: 12        Unnamed: 13  Unnamed: 14  \
# 0                13+          NaN                18+          NaN
# 1  Count of Duration  Sum of Year  Count of Duration  Sum of Year
# 2                  4         8076                  2         4040
#
#          Unnamed: 15  Unnamed: 16        Unnamed: 17  Unnamed: 18  \
# 0                16+          NaN                All          NaN
# ...

# %%
data.tail(3)
# Out:
#                  Name    Year Age Rating Duration Category      Unnamed: 6  \
# 2726       Article 15  2019.0        16+    2h 5m   Dramas NaN         NaN
# 2727    We Are Family  2010.0        13+   1h 58m   Dramas NaN         NaN
# 2728  Ajeeb Daastaans  2021.0        18+   2h 22m   Dramas NaN         NaN
#
#       Unnamed: 7 Unnamed: 8 Age Rating.1  ... Unnamed: 11 Unnamed: 12  \
# 2726         NaN        NaN          NaN  ...         NaN         NaN
# 2727         NaN        NaN          NaN  ...         NaN         NaN
# 2728         NaN        NaN          NaN  ...         NaN         NaN
#
#      Unnamed: 13 Unnamed: 14 Unnamed: 15 Unnamed: 16 Unnamed: 17 Unnamed: 18  \
# 2726         NaN         NaN         NaN         NaN         NaN         NaN
# 2727         NaN         NaN         NaN         NaN         NaN         NaN
# 2728         NaN         NaN         NaN         NaN         NaN         NaN
#
#      Unnamed: 19 Unnamed: 20
# 2726         NaN         NaN
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2729 entries, 0 to 2728
# Data columns (total 21 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          2728 non-null   object
#  1   Year          2704 non-null   float64
#  2   Age Rating    2704 non-null   object
#  3   Duration      2728 non-null   object
#  4   Category      2727 non-null   object
#  5                 0 non-null      float64
#  6   Unnamed: 6    0 non-null      float64
#  7   Unnamed: 7    0 non-null      float64
#  8   Unnamed: 8    144 non-null    object
#  9   Age Rating.1  66 non-null     object
#  10  Values        65 non-null     object
#  11  Unnamed: 11   76 non-null     object
#  12  Unnamed: 12   75 non-null     object
#  13  Unnamed: 13   50 non-null     object
#  14  Unnamed: 14   49 non-null     object
#  15  Unnamed: 15   47 non-null     object
#  16  Unnamed: 16   46 non-null     object
#  17  Unnamed: 17   33 non-null     object
# ...

# %%
data.describe()
# Out:
#               Year       Unnamed: 6  Unnamed: 7
# count  2704.000000  0.0         0.0         0.0
# mean   2014.891642  NaN         NaN         NaN
# std       8.332022  NaN         NaN         NaN
# min    1954.000000  NaN         NaN         NaN
# 25%    2012.000000  NaN         NaN         NaN
# 50%    2018.000000  NaN         NaN         NaN
# 75%    2020.000000  NaN         NaN         NaN
# max    2022.000000  NaN         NaN         NaN

# %%
data.shape
# Out:
# (2729, 21)

# %%
data.size
# Out:
# 57309

# %%
data.columns
# Out:
# Index(['Name', 'Year', 'Age Rating', 'Duration', 'Category', ' ', 'Unnamed: 6',
#        'Unnamed: 7', 'Unnamed: 8', 'Age Rating.1', 'Values', 'Unnamed: 11',
#        'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15',
#        'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19',
#        'Unnamed: 20'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Name             object
# Year            float64
# Age Rating       object
# Duration         object
# Category         object
#                 float64
# Unnamed: 6      float64
# Unnamed: 7      float64
# Unnamed: 8       object
# Age Rating.1     object
# Values           object
# Unnamed: 11      object
# Unnamed: 12      object
# Unnamed: 13      object
# Unnamed: 14      object
# Unnamed: 15      object
# Unnamed: 16      object
# Unnamed: 17      object
# Unnamed: 18      object
# Unnamed: 19      object
# Unnamed: 20      object
# dtype: object

# %% [markdown]
# ## To check duplicate values##

# %%
data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2724    False
# 2725    False
# 2726    False
# 2727    False
# 2728    False
# Length: 2729, dtype: bool

# %% [markdown]
# ##check duplicate record##

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Name, Year, Age Rating, Duration, Category,  , Unnamed: 6, Unnamed: 7, Unnamed: 8, Age Rating.1, Values, Unnamed: 11, Unnamed: 12, Unnamed: 13, Unnamed: 14, Unnamed: 15, Unnamed: 16, Unnamed: 17, Unnamed: 18, Unnamed: 19, Unnamed: 20]
# Index: []
#
# [0 rows x 21 columns]

# %% [markdown]
# ##remove duplicate record##

# %%
data.drop_duplicates()
# Out:
#                             Name    Year Age Rating Duration  \
# 0                  The Sea Beast  2022.0         7+   1h 59m
# 1             Sonic the Hedgehog  2020.0         7+   1h 41m
# 2                  Tom and Jerry  2021.0         7+   1h 41m
# 3               We Can Be Heroes  2020.0         7+   1h 40m
# 4         STAND BY ME Doraemon 2  2020.0         7+   1h 37m
# ...                          ...     ...        ...      ...
# 2724                         Mom  2017.0        16+   2h 18m
# 2725  The Legend of Bhagat Singh  2002.0        16+   2h 35m
# 2726                  Article 15  2019.0        16+    2h 5m
# 2727               We Are Family  2010.0        13+   1h 58m
# 2728             Ajeeb Daastaans  2021.0        18+   2h 22m
#
#                        Category      Unnamed: 6  Unnamed: 7 Unnamed: 8  \
# 0          Kids & Family Movies NaN         NaN         NaN        NaN
# 1          Kids & Family Movies NaN         NaN         NaN   Duration
# ...

# %% [markdown]
# ##check null values##

# %%
data.isnull().sum()
# Out:
# Name               1
# Year              25
# Age Rating        25
# Duration           1
# Category           2
#                 2729
# Unnamed: 6      2729
# Unnamed: 7      2729
# Unnamed: 8      2585
# Age Rating.1    2663
# Values          2664
# Unnamed: 11     2653
# Unnamed: 12     2654
# Unnamed: 13     2679
# Unnamed: 14     2680
# Unnamed: 15     2682
# Unnamed: 16     2683
# Unnamed: 17     2696
# Unnamed: 18     2697
# Unnamed: 19     2585
# Unnamed: 20     2585
# dtype: int64

# %% [markdown]
# ##null values exist in heatmap##

# %%
import seaborn as sns

# %%
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
data.dtypes
# Out:
# Name             object
# Year            float64
# Age Rating       object
# Duration         object
# Category         object
#                 float64
# Unnamed: 6      float64
# Unnamed: 7      float64
# Unnamed: 8       object
# Age Rating.1     object
# Values           object
# Unnamed: 11      object
# Unnamed: 12      object
# Unnamed: 13      object
# Unnamed: 14      object
# Unnamed: 15      object
# Unnamed: 16      object
# Unnamed: 17      object
# Unnamed: 18      object
# Unnamed: 19      object
# Unnamed: 20      object
# dtype: object

# %%
data.head(1)
# Out:
#             Name    Year Age Rating Duration              Category      \
# 0  The Sea Beast  2022.0         7+   1h 59m  Kids & Family Movies NaN
#
#    Unnamed: 6  Unnamed: 7 Unnamed: 8 Age Rating.1  ... Unnamed: 11  \
# 0         NaN         NaN        NaN           7+  ...         13+
#
#   Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15 Unnamed: 16 Unnamed: 17  \
# 0         NaN         18+         NaN         16+         NaN         All
#
#   Unnamed: 18              Unnamed: 19        Unnamed: 20
# 0         NaN  Total Count of Duration  Total Sum of Year
#
# [1 rows x 21 columns]

# %%
data['Year'].max()
# Out:
# 2022.0

# %%
data['Name']
# Out:
# 0                    The Sea Beast
# 1               Sonic the Hedgehog
# 2                    Tom and Jerry
# 3                 We Can Be Heroes
# 4           STAND BY ME Doraemon 2
#                    ...
# 2724                           Mom
# 2725    The Legend of Bhagat Singh
# 2726                    Article 15
# 2727                 We Are Family
# 2728               Ajeeb Daastaans
# Name: Name, Length: 2729, dtype: object

# %%
data['Age Rating']
# Out:
# 0        7+
# 1        7+
# 2        7+
# 3        7+
# 4        7+
#        ...
# 2724    16+
# 2725    16+
# 2726    16+
# 2727    13+
# 2728    18+
# Name: Age Rating, Length: 2729, dtype: object

# %% [markdown]
# ##which year tv shows and movies are release##

# %%
data[(data['Year']=='2022')&(data['Category']=='Kids & Family Movies')]
# Out:
# Empty DataFrame
# Columns: [Name, Year, Age Rating, Duration, Category,  , Unnamed: 6, Unnamed: 7, Unnamed: 8, Age Rating.1, Values, Unnamed: 11, Unnamed: 12, Unnamed: 13, Unnamed: 14, Unnamed: 15, Unnamed: 16, Unnamed: 17, Unnamed: 18, Unnamed: 19, Unnamed: 20]
# Index: []
#
# [0 rows x 21 columns]

# %%
data[(data['Year']=='2022')|(data['Category']=='Kids & Family Movies')|(data['Category']=='Dramas')]
# Out:
#                         Name    Year Age Rating Duration  \
# 0              The Sea Beast  2022.0         7+   1h 59m
# 1         Sonic the Hedgehog  2020.0         7+   1h 41m
# 2              Tom and Jerry  2021.0         7+   1h 41m
# 3           We Can Be Heroes  2020.0         7+   1h 40m
# 4     STAND BY ME Doraemon 2  2020.0         7+   1h 37m
# ...                      ...     ...        ...      ...
# 2721             To the Bone  2017.0        16+   1h 47m
# 2724                     Mom  2017.0        16+   2h 18m
# 2726              Article 15  2019.0        16+    2h 5m
# 2727           We Are Family  2010.0        13+   1h 58m
# 2728         Ajeeb Daastaans  2021.0        18+   2h 22m
#
#                   Category      Unnamed: 6  Unnamed: 7 Unnamed: 8  \
# 0     Kids & Family Movies NaN         NaN         NaN        NaN
# 1     Kids & Family Movies NaN         NaN         NaN   Duration
# 2     Kids & Family Movies NaN         NaN         NaN     1h 30m
# ...

# %%
[(data['Category']=='Kids & Family Movies')|(data['Category']=='Dramas')]
# Out:
# [0        True
#  1        True
#  2        True
#  3        True
#  4        True
#          ...
#  2724     True
#  2725    False
#  2726     True
#  2727     True
#  2728     True
#  Name: Category, Length: 2729, dtype: bool]

# %%
import matplotlib.pyplot as plt

# %%
data.head(2)
# Out:
#                  Name    Year Age Rating Duration              Category      \
# 0       The Sea Beast  2022.0         7+   1h 59m  Kids & Family Movies NaN
# 1  Sonic the Hedgehog  2020.0         7+   1h 41m  Kids & Family Movies NaN
#
#    Unnamed: 6  Unnamed: 7 Unnamed: 8       Age Rating.1  ...  \
# 0         NaN         NaN        NaN                 7+  ...
# 1         NaN         NaN   Duration  Count of Duration  ...
#
#          Unnamed: 11  Unnamed: 12        Unnamed: 13  Unnamed: 14  \
# 0                13+          NaN                18+          NaN
# 1  Count of Duration  Sum of Year  Count of Duration  Sum of Year
#
#          Unnamed: 15  Unnamed: 16        Unnamed: 17  Unnamed: 18  \
# 0                16+          NaN                All          NaN
# 1  Count of Duration  Sum of Year  Count of Duration  Sum of Year
#
#                Unnamed: 19        Unnamed: 20
# 0  Total Count of Duration  Total Sum of Year
# 1                      NaN                NaN
#
# ...

# %% [markdown]
# ##barplot##

# %%
data.head()
# Out:
#                      Name    Year Age Rating Duration              Category  \
# 0           The Sea Beast  2022.0         7+   1h 59m  Kids & Family Movies
# 1      Sonic the Hedgehog  2020.0         7+   1h 41m  Kids & Family Movies
# 2           Tom and Jerry  2021.0         7+   1h 41m  Kids & Family Movies
# 3        We Can Be Heroes  2020.0         7+   1h 40m  Kids & Family Movies
# 4  STAND BY ME Doraemon 2  2020.0         7+   1h 37m  Kids & Family Movies
#
#        Unnamed: 6  Unnamed: 7 Unnamed: 8       Age Rating.1  ...  \
# 0 NaN         NaN         NaN        NaN                 7+  ...
# 1 NaN         NaN         NaN   Duration  Count of Duration  ...
# 2 NaN         NaN         NaN     1h 30m                  7  ...
# 3 NaN         NaN         NaN     1h 46m                  7  ...
# 4 NaN         NaN         NaN     1h 59m                  4  ...
#
#          Unnamed: 11  Unnamed: 12        Unnamed: 13  Unnamed: 14  \
# ...

# %%
data['Age Rating'].max
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.max of 0        7+
# 1        7+
# 2        7+
# 3        7+
# 4        7+
#        ...
# 2724    16+
# 2725    16+
# 2726    16+
# 2727    13+
# 2728    18+
# Name: Age Rating, Length: 2729, dtype: object>

# %%
data['Year'].max()
# Out:
# 2022.0

# %%
data.head(5)
# Out:
#                      Name    Year Age Rating Duration              Category  \
# 0           The Sea Beast  2022.0         7+   1h 59m  Kids & Family Movies
# 1      Sonic the Hedgehog  2020.0         7+   1h 41m  Kids & Family Movies
# 2           Tom and Jerry  2021.0         7+   1h 41m  Kids & Family Movies
# 3        We Can Be Heroes  2020.0         7+   1h 40m  Kids & Family Movies
# 4  STAND BY ME Doraemon 2  2020.0         7+   1h 37m  Kids & Family Movies
#
#        Unnamed: 6  Unnamed: 7 Unnamed: 8       Age Rating.1  ...  \
# 0 NaN         NaN         NaN        NaN                 7+  ...
# 1 NaN         NaN         NaN   Duration  Count of Duration  ...
# 2 NaN         NaN         NaN     1h 30m                  7  ...
# 3 NaN         NaN         NaN     1h 46m                  7  ...
# 4 NaN         NaN         NaN     1h 59m                  4  ...
#
#          Unnamed: 11  Unnamed: 12        Unnamed: 13  Unnamed: 14  \
# ...

# %% [markdown]
# ##how many tv shows and dataset are there in this dataset show the graph####

# %%
 [data['Category']=='Dramas']
# Out:
# [0       False
#  1       False
#  2       False
#  3       False
#  4       False
#          ...
#  2724     True
#  2725    False
#  2726     True
#  2727     True
#  2728     True
#  Name: Category, Length: 2729, dtype: bool]

# %%
sns.barplot(x='Category',y='Year',data=data)
# Out:
# <Axes: xlabel='Category', ylabel='Year'>
